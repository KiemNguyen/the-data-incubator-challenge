# %%
import pandas as pd
import numpy as np
import re
from glob import glob
from datetime import datetime
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Read in the data

# %%
path = 'house-office-expenditures-with-readme/'

# %%
# Data in 2017Q2-house-disburse-detail.csv is off by one column. Let's fix it
df_2017Q2_detail = pd.read_csv(path + '2017Q2-house-disburse-detail.csv', encoding='ISO-8859-1', header=0) 
df_2017Q2_detail.head()
# Out:
#   BIOGUIDE_ID                      OFFICE QUARTER               PROGRAM  \
# 0         NaN  2017 OFFICE OF THE SPEAKER  2017Q2  GENERAL EXPENDITURES
# 1         NaN  2017 OFFICE OF THE SPEAKER  2017Q2  GENERAL EXPENDITURES
# 2         NaN  2017 OFFICE OF THE SPEAKER  2017Q2  GENERAL EXPENDITURES
# 3         NaN  2017 OFFICE OF THE SPEAKER  2017Q2  GENERAL EXPENDITURES
# 4         NaN  2017 OFFICE OF THE SPEAKER  2017Q2  GENERAL EXPENDITURES
#
#                  CATEGORY SORT SEQUENCE DATE TRANSCODE             RECORDID  \
# 0  PERSONNEL COMPENSATION                                 ALTHOUSE JOSHUA S
# 1  PERSONNEL COMPENSATION                                  ANDRES DOUGLAS R
# 2  PERSONNEL COMPENSATION                                  ANDREWS THOMAS S
# 3  PERSONNEL COMPENSATION                                   ANTELL GEOFFREY
# 4  PERSONNEL COMPENSATION                               BENJAMIN WILLIAM C.
#
#     PAYEE START DATE                        END DATE   PURPOSE AMOUNT  YEAR
# 0  4/1/17    6/30/17  CONSERVATIVE OUTREACH DIRECTOR  20000.01   2017   NaN
# 1  4/1/17    6/30/17                 PRESS SECRETARY  27500.01   2017   NaN
# 2  4/1/17    6/30/17        MEMBER SERVICES DIRECTOR  32500.00   2017   NaN
# 3  4/1/17    6/30/17  ASST TO THE SPEAKER FOR POLICY  41250.00   2017   NaN
# 4  4/1/17    6/30/17            SYSTEM ADMINISTRATOR  13250.01   2017   NaN

# %%
# Shift data to the right columns
df_2017Q2_detail[df_2017Q2_detail.columns[-9:]] = df_2017Q2_detail[df_2017Q2_detail.columns[-10:-1].values]
df_2017Q2_detail[df_2017Q2_detail.columns[-10]] = ''

# %%
df_2017Q2_detail.head()
# Out:
#   BIOGUIDE_ID                      OFFICE QUARTER               PROGRAM  \
# 0         NaN  2017 OFFICE OF THE SPEAKER  2017Q2  GENERAL EXPENDITURES
# 1         NaN  2017 OFFICE OF THE SPEAKER  2017Q2  GENERAL EXPENDITURES
# 2         NaN  2017 OFFICE OF THE SPEAKER  2017Q2  GENERAL EXPENDITURES
# 3         NaN  2017 OFFICE OF THE SPEAKER  2017Q2  GENERAL EXPENDITURES
# 4         NaN  2017 OFFICE OF THE SPEAKER  2017Q2  GENERAL EXPENDITURES
#
#                  CATEGORY SORT SEQUENCE DATE TRANSCODE RECORDID  \
# 0  PERSONNEL COMPENSATION
# 1  PERSONNEL COMPENSATION
# 2  PERSONNEL COMPENSATION
# 3  PERSONNEL COMPENSATION
# 4  PERSONNEL COMPENSATION
#
#                  PAYEE START DATE END DATE                         PURPOSE  \
# 0    ALTHOUSE JOSHUA S     4/1/17  6/30/17  CONSERVATIVE OUTREACH DIRECTOR
# 1     ANDRES DOUGLAS R     4/1/17  6/30/17                 PRESS SECRETARY
# 2     ANDREWS THOMAS S     4/1/17  6/30/17        MEMBER SERVICES DIRECTOR
# 3      ANTELL GEOFFREY     4/1/17  6/30/17  ASST TO THE SPEAKER FOR POLICY
# 4  BENJAMIN WILLIAM C.     4/1/17  6/30/17            SYSTEM ADMINISTRATOR
#
#      AMOUNT  YEAR
# 0  20000.01  2017
# 1  27500.01  2017
# 2  32500.00  2017
# 3  41250.00  2017
# 4  13250.01  2017

# %%
df_2017Q2_detail['AMOUNT'].dtype
# Out:
# dtype('float64')

# %%
# Let's work on rest of the detail files
df = pd.DataFrame()
all_detail_files = glob(path + '*-detail.csv')
for file in [s for s in all_detail_files if '2017Q2' not in s]:
    detail_files = pd.read_csv(file, encoding='ISO-8859-1', header=0) 
    df = pd.concat([df, detail_files], ignore_index=True)

# %%
df.shape
# Out:
# (3435911, 17)

# %%
# Concatenate these detail files with the previous fixed 2017Q2 detail file
df = pd.concat([df, df_2017Q2_detail], ignore_index=True)
df.shape
# Out:
# (3542048, 17)

# %%
df.head()
# Out:
#    AMOUNT BIOGUIDE_ID                CATEGORY DATE  END DATE          OFFICE  \
# 0  455.00         NaN          OTHER SERVICES  NaN  03/02/10  COMMUNICATIONS
# 1   47.26         NaN  SUPPLIES AND MATERIALS  NaN  11/28/09  COMMUNICATIONS
# 2  250.00         NaN  SUPPLIES AND MATERIALS  NaN  12/21/09  COMMUNICATIONS
# 3  436.00         NaN  SUPPLIES AND MATERIALS  NaN  12/21/09  COMMUNICATIONS
# 4   37.90         NaN  SUPPLIES AND MATERIALS  NaN  12/21/09  COMMUNICATIONS
#
#                                                PAYEE PROGRAM  \
# 0  03Â­10       P2 MFP0003226                    ...     NaN
# 1       02Â­05       P2    MFP0003219       ALLSTEEL     NaN
# 2  03Â­05       P2    OSM42304         CDW GOVERN...     NaN
# 3        03Â­05       P2    OSM42304              DO     NaN
# 4        03Â­05       P2    OSM42304              DO     NaN
#
#                           PURPOSE QUARTER  \
# 0  NON-TECHNOLOGY SERVICE CONTRCT  2010Q1
# 1             HABITATION EXPENSES  2010Q1
# 2         OFFICE SUPPLIES OUTSIDE  2010Q1
# 3         OFFICE SUPPLIES OUTSIDE  2010Q1
# 4         OFFICE SUPPLIES OUTSIDE  2010Q1
#
#                                        RECIP (orig.) RECORDID SORT SEQUENCE  \
# 0  03Â­10       P2 MFP0003226                    ...      NaN           NaN
# 1       02Â­05       P2    MFP0003219       ALLSTEEL      NaN           NaN
# 2  03Â­05       P2    OSM42304         CDW GOVERN...      NaN           NaN
# 3        03Â­05       P2    OSM42304              DO      NaN           NaN
# 4        03Â­05       P2    OSM42304              DO      NaN           NaN
#
#   START DATE TRANSCODE TRANSCODELONG              YEAR
# 0   03/02/10       NaN           NaN  FISCAL YEAR 2010
# 1   11/28/09       NaN           NaN  FISCAL YEAR 2010
# 2   12/21/09       NaN           NaN  FISCAL YEAR 2010
# 3   12/21/09       NaN           NaN  FISCAL YEAR 2010
# 4   12/21/09       NaN           NaN  FISCAL YEAR 2010

# %%
df.dtypes
# Out:
# AMOUNT           object
# BIOGUIDE_ID      object
# CATEGORY         object
# DATE             object
# END DATE         object
# OFFICE           object
# PAYEE            object
# PROGRAM          object
# PURPOSE          object
# QUARTER          object
# RECIP (orig.)    object
# RECORDID         object
# SORT SEQUENCE    object
# START DATE       object
# TRANSCODE        object
# TRANSCODELONG    object
# YEAR             object
# dtype: object

# %% [markdown]
# ### Function to convert AMOUNT from string to numeric

# %%
def convert_currency(val):
    # Convert the string number value to a float by removing commas, then convert to float type
    new_val = str(val)
    return float(new_val.replace(',',''))

# %%
df['AMOUNT'] = df['AMOUNT'].apply(convert_currency)
df.dtypes
# Out:
# AMOUNT           float64
# BIOGUIDE_ID       object
# CATEGORY          object
# DATE              object
# END DATE          object
# OFFICE            object
# PAYEE             object
# PROGRAM           object
# PURPOSE           object
# QUARTER           object
# RECIP (orig.)     object
# RECORDID          object
# SORT SEQUENCE     object
# START DATE        object
# TRANSCODE         object
# TRANSCODELONG     object
# YEAR              object
# dtype: object

# %% [markdown]
# ### Save the cleaned data file

# %%
df.to_csv('detail_files.csv', index=False)

# %% [markdown]
# ### Read in the new cleaned data file

# %%
df = pd.read_csv('detail_files.csv')

# %% [markdown]
# ### Question 1: What is the total of all the payments in the dataset?

# %%
total_payment = df['AMOUNT'].sum()
print(f'Question 1: {total_payment}')
# Out:
# Question 1: 13660703793.310003

# %% [markdown]
# ### Question 2: Define the 'COVERAGE PERIOD' for each payment as the difference (in days) between 'END DATE' and 'START DATE'. What is the standard deviation in 'COVERAGE PERIOD'? Only consider payments with strictly positive amounts.

# %%
# Convert START DATE and END DATE from string to datetime type
df['START DATE'] = pd.to_datetime(df['START DATE'], format='%m/%d/%y', errors = 'coerce')
df['END DATE'] = pd.to_datetime(df['END DATE'], format='%m/%d/%y', errors = 'coerce')
df.dtypes
# Out:
# AMOUNT                  float64
# BIOGUIDE_ID              object
# CATEGORY                 object
# DATE                     object
# END DATE         datetime64[ns]
# OFFICE                   object
# PAYEE                    object
# PROGRAM                  object
# PURPOSE                  object
# QUARTER                  object
# RECIP (orig.)            object
# RECORDID                 object
# SORT SEQUENCE            object
# START DATE       datetime64[ns]
# TRANSCODE                object
# TRANSCODELONG            object
# YEAR                     object
# dtype: object

# %%
df['COVERAGE PERIOD'] = df['END DATE'] - df['START DATE']
df['COVERAGE PERIOD']
# Out:
# 0          0 days
# 1          0 days
# 2          0 days
# 3          0 days
# 4          0 days
# 5         30 days
# 6         27 days
# 7          0 days
# 8          0 days
# 9          6 days
# 10         6 days
# 11         0 days
# 12         0 days
# 13        30 days
# 14         9 days
# 15         9 days
# 16         9 days
# 17         9 days
# 18         9 days
# 19         9 days
# 20         9 days
# 21         9 days
# 22        23 days
# 23        23 days
# 24        23 days
# 25        23 days
# 26        23 days
# 27        23 days
# 28        23 days
# 29        23 days
#             ...
# 3542018       NaT
# 3542019       NaT
# 3542020       NaT
# 3542021   27 days
# 3542022   29 days
# 3542023   29 days
# 3542024   30 days
# 3542025   30 days
# 3542026   29 days
# 3542027   29 days
# 3542028   30 days
# 3542029   56 days
# 3542030   30 days
# 3542031   29 days
# 3542032   29 days
# 3542033   60 days
# 3542034   29 days
# 3542035   29 days
# 3542036   30 days
# 3542037   29 days
# 3542038   30 days
# 3542039   30 days
# 3542040       NaT
# 3542041       NaT
# 3542042       NaT
# 3542043   29 days
# 3542044   29 days
# 3542045       NaT
# 3542046       NaT
# 3542047       NaT
# Name: COVERAGE PERIOD, Length: 3542048, dtype: timedelta64[ns]

# %%
std = df[df['AMOUNT']>0]['COVERAGE PERIOD'].std().total_seconds()/60/60/24
print(f'Question 2: {std:.10f}')
# Out:
# Question 2: 61.8808082569

# %% [markdown]
# ### Question 3: What was the average annual expenditure with a 'START DATE' date between January 1, 2010 and December 31, 2016 (inclusive)? Only consider payments with strictly positive amounts.

# %%
df_2010_2016 =  df[(df['START DATE']>='2010-01-01') & (df['START DATE']<='2016-12-31') & (df['AMOUNT']>0)]
df_2010_2016.shape
# Out:
# (2692214, 18)

# %%
total = df_2010_2016['AMOUNT'].sum()/7
print(f'Question 3: {total}')
# Out:
# Question 3: 1209984621.0528576

# %% [markdown]
# ### Question 4: Find the 'OFFICE' with the highest total expenditures with a 'START DATE' in 2016. For this office, find the 'PURPOSE' that accounts for the highest total expenditures. What fraction of the total expenditures (all records, all offices) with a 'START DATE' in 2016 do these expenditures amount to?

# %%
df_2016 =  df[(df['START DATE']>='2016-01-01') & (df['START DATE']<='2016-12-31')]
df_2016.head()
# Out:
#         AMOUNT BIOGUIDE_ID                CATEGORY   DATE   END DATE  \
# 459592    79.0     F000460  SUPPLIES AND MATERIALS  01-05 2017-01-08
# 466444  3250.0     G000569  SUPPLIES AND MATERIALS  03-31 2016-12-31
# 480980  9998.0     L000554  SUPPLIES AND MATERIALS  01-09 2016-12-31
# 490368  5850.0     N000179          OTHER SERVICES  01-05 2016-12-31
# 492619   780.0     O000170  SUPPLIES AND MATERIALS  01-05 2016-12-31
#
#                           OFFICE                        PAYEE PROGRAM  \
# 459592     HON. BLAKE FARENTHOLD               ROCKPORT PILOT     NaN
# 466444     HON. MICHAEL G. GRIMM  ARISTOTLE INTERNATIONAL INC     NaN
# 480980    HON. FRANK A. LOBIONDO     MORNINGSIDE PARTNERS LLC     NaN
# 490368  HON. GRACE F. NAPOLITANO                 BLOOMBERG LP     NaN
# 492619         HON. BETO OROURKE              WYSONG, DAVID M     NaN
#
#                              PURPOSE QUARTER                RECIP (orig.)  \
# 459592  PUBLICATIONS/REFERENCE MAT'L  2015Q1               ROCKPORT PILOT
# 466444  PUBLICATIONS/REFERENCE MAT'L  2015Q1  ARISTOTLE INTERNATIONAL INC
# 480980  PUBLICATIONS/REFERENCE MAT'L  2015Q1     MORNINGSIDE PARTNERS LLC
# 490368  NON-TECHNOLOGY SERVICE CONTR  2015Q1                 BLOOMBERG LP
# 492619  PUBLICATIONS/REFERENCE MAT'L  2015Q1              WYSONG, DAVID M
#
#         RECORDID SORT SEQUENCE START DATE TRANSCODE     TRANSCODELONG  YEAR  \
# 459592  E0231342           NaN 2016-01-09        AP  Accounts payable  2014
# 466444  E0262887           NaN 2016-01-01        AP  Accounts payable  2015
# 480980  00768917           NaN 2016-01-01        AP  Accounts payable  2014
# 490368  E0232243           NaN 2016-01-01        AP  Accounts payable  2014
# 492619  E0232032           NaN 2016-01-01        AP  Accounts payable  2014
#
#        COVERAGE PERIOD
# 459592        365 days
# 466444        365 days
# 480980        365 days
# 490368        365 days
# 492619        365 days

# %%
df_2016.groupby(['OFFICE'])[['AMOUNT']].sum().sort_values(by='AMOUNT', ascending=False).head()
# Out:
#                                                  AMOUNT
# OFFICE
# GOVERNMENT CONTRIBUTIONS                   1.664793e+08
# CHIEF ADMIN OFCR OF THE HOUSE              1.199160e+08
# COMMITTEE ON APPROPRIATIONS                2.516048e+07
# FISCAL YEAR 2017 GOVERNMENT CONTRIBUTIONS  2.330127e+07
# CLERK OF THE HOUSE                         2.291365e+07

# %%
highest_total_office = df_2016[df_2016['OFFICE']=='GOVERNMENT CONTRIBUTIONS']
highest_total_office.head()
# Out:
#           AMOUNT BIOGUIDE_ID                CATEGORY   DATE   END DATE  \
# 1198188  2752.04         NaN  PERSONNEL COMPENSATION    NaN 2016-04-30
# 1198189   811.92         NaN  PERSONNEL COMPENSATION    NaN 2016-04-30
# 1198191  7062.41         NaN  PERSONNEL COMPENSATION    NaN 2016-06-30
# 1198192  1834.59         NaN  PERSONNEL COMPENSATION    NaN 2016-06-30
# 1198193    21.50         NaN      PERSONNEL BENEFITS  04-01 2016-02-29
#
#                            OFFICE               PAYEE PROGRAM  \
# 1198188  GOVERNMENT CONTRIBUTIONS   STARKEY,CHARLES J     NaN
# 1198189  GOVERNMENT CONTRIBUTIONS       WRIGHT,ASLI V     NaN
# 1198191  GOVERNMENT CONTRIBUTIONS   STARKEY,CHARLES J     NaN
# 1198192  GOVERNMENT CONTRIBUTIONS       WRIGHT,ASLI V     NaN
# 1198193  GOVERNMENT CONTRIBUTIONS  SOLLAZZO, AMANDA M     NaN
#
#                              PURPOSE QUARTER       RECIP (orig.)  RECORDID  \
# 1198188  BUSINESS CONTINUITY MANAGER  2016Q2   STARKEY,CHARLES J       NaN
# 1198189  SENIOR CONTRACTS SPECIALIST  2016Q2       WRIGHT,ASLI V       NaN
# 1198191  BUSINESS CONTINUITY MANAGER  2016Q2   STARKEY,CHARLES J       NaN
# 1198192  SENIOR CONTRACTS SPECIALIST  2016Q2       WRIGHT,ASLI V       NaN
# 1198193             TRANSIT BENEFITS  2016Q2  SOLLAZZO, AMANDA M  E0386764
#
#         SORT SEQUENCE START DATE TRANSCODE     TRANSCODELONG  \
# 1198188           NaN 2016-04-01       NaN               NaN
# 1198189           NaN 2016-04-01       NaN               NaN
# 1198191           NaN 2016-05-01       NaN               NaN
# 1198192           NaN 2016-05-01       NaN               NaN
# 1198193           NaN 2016-02-23        AP  Accounts payable
#
#                      YEAR COVERAGE PERIOD
# 1198188  FISCAL YEAR 2016         29 days
# 1198189  FISCAL YEAR 2016         29 days
# 1198191  FISCAL YEAR 2016         60 days
# 1198192  FISCAL YEAR 2016         60 days
# 1198193  FISCAL YEAR 2016          6 days

# %%
highest_total_office.groupby(['PURPOSE'])[['AMOUNT']].sum().sort_values(by='AMOUNT', ascending=False).head()
# Out:
#                        AMOUNT
# PURPOSE
# FERS              62452380.59
# HEALTH INSURANCE  26565188.31
# STUDENT LOANS     14661130.44
# TSP MATCHING      13976878.79
# FURTHER FERS RAE  11598185.14

# %%
fraction = df_2016[df_2016['PURPOSE']=='FERS']['AMOUNT'].sum() / df_2016['AMOUNT'].sum()
print(f'Question 4: {fraction:.10f}')
# Out:
# Question 4: 0.0568838384

# %% [markdown]
# ### Question 5: What was the highest average staff salary among all representatives in 2016? Assume staff sizes is equal to the number of unique payees in the 'PERSONNEL COMPENSATION' category for each representative.

# %%
df_staff_2016 = df_2016[(df_2016['CATEGORY']=='PERSONNEL COMPENSATION') & (df_2016['BIOGUIDE_ID'].notnull())]
df_staff_2016.head()
# Out:
#            AMOUNT BIOGUIDE_ID                CATEGORY DATE   END DATE  \
# 1114547   9687.50     A000374  PERSONNEL COMPENSATION  NaN 2016-06-30
# 1114548  17062.50     A000374  PERSONNEL COMPENSATION  NaN 2016-06-30
# 1114549  12999.99     A000374  PERSONNEL COMPENSATION  NaN 2016-06-30
# 1114550  11000.00     A000374  PERSONNEL COMPENSATION  NaN 2016-06-30
# 1114551  14937.50     A000374  PERSONNEL COMPENSATION  NaN 2016-06-30
#
#                      OFFICE             PAYEE PROGRAM  \
# 1114547  HON. RALPH ABRAHAM    ARNOLD,EMILY M     NaN
# 1114548  HON. RALPH ABRAHAM    AVERY,ROBERT C     NaN
# 1114549  HON. RALPH ABRAHAM  BARRON,PATRICK C     NaN
# 1114550  HON. RALPH ABRAHAM     BOIES,LILIA C     NaN
# 1114551  HON. RALPH ABRAHAM      BROWN,ALAN K     NaN
#
#                                PURPOSE QUARTER     RECIP (orig.) RECORDID  \
# 1114547                     CASEWORKER  2016Q2    ARNOLD,EMILY M      NaN
# 1114548        COMMUNICATIONS DIRECTOR  2016Q2    AVERY,ROBERT C      NaN
# 1114549          LEGISLATIVE ASSISTANT  2016Q2  BARRON,PATRICK C      NaN
# 1114550                 OFFICE MANAGER  2016Q2     BOIES,LILIA C      NaN
# 1114551  DIRECTOR OF DISTRICT OUTREACH  2016Q2      BROWN,ALAN K      NaN
#
#         SORT SEQUENCE START DATE TRANSCODE TRANSCODELONG  YEAR COVERAGE PERIOD
# 1114547           NaN 2016-04-01       NaN           NaN  2016         90 days
# 1114548           NaN 2016-04-01       NaN           NaN  2016         90 days
# 1114549           NaN 2016-04-01       NaN           NaN  2016         90 days
# 1114550           NaN 2016-04-01       NaN           NaN  2016         90 days
# 1114551           NaN 2016-04-01       NaN           NaN  2016         90 days

# %%
# Clean data in PAYEE
df_staff_2016['PAYEE'] = df_staff_2016['PAYEE'].astype(str).map(lambda x: x.replace(',','').replace('.','').replace(' ',''))

# %%
groupby_staff = pd.DataFrame({'AMOUNT_SUM' : df_staff_2016.groupby(['BIOGUIDE_ID', 'PAYEE'])['AMOUNT'].sum()}).reset_index()

# %%
groupby_staff.head()
# Out:
#   BIOGUIDE_ID              PAYEE  AMOUNT_SUM
# 0     A000055   ABERNATHYPAMELAM    57131.95
# 1     A000055  CHRISTENSENAUTUMN     6500.00
# 2     A000055       CLARKCARSONG    59202.74
# 3     A000055        DAWSONMARKE    11966.67
# 4     A000055   DONCHESMICHELLEM    15999.96

# %%
highest_average_salary = pd.DataFrame(groupby_staff.groupby(['BIOGUIDE_ID'])['AMOUNT_SUM'].mean()).sort_values('AMOUNT_SUM', ascending = False)['AMOUNT_SUM'].values[0]
print(f'Question 5: {highest_average_salary:.10f}')
# Out:
# Question 5: 65064.5381250000

# %% [markdown]
# ### Question 6: What was the median rate of annual turnover in staff between 2011 and 2016 (inclusive)? Turnover for 2011 should be calculated as the fraction of a representative's staff from 2010 who did not carry over to 2011. Only consider representatives who served for at least 4 years and had staff size of at least 5 every year that they served.

# %% [markdown]
# ### Question 7: What percentage of the expenditures of the top 20 spenders in 2016 come from members of the Democratic Party? Representatives are identified by their 'BIOGUIDE_ID', which can be used to look up representatives with ProPublica's Congress API to find their party affiliation. Consider an expenditure as being in 2016 if its 'START DATE' is in 2016.
